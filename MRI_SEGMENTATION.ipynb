# %% [markdown]
# <a href="https://colab.research.google.com/github/dubesar/MRI-Segmentation-1/blob/master/MRI_SEGMENTATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount = True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from fastai import *
from fastai.vision import *
from fastai.core import *

# %%
path = Path("/content/drive/My Drive/Alzheimer's Dataset")
data= ImageDataBunch.from_folder(path,train = '.',valid_pct = 0.2, ds_tfms = get_transforms(),size = 224 , num_workers= 4).normalize(imagenet_stats)

# %%
data.show_batch()

# %%
learn = create_cnn(data,models.resnet18,metrics = accuracy)
learn.fit_one_cycle(10,1e-3,1e-2)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:105: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.torch/models/resnet18-5c106cde.pth
# 46827520it [00:02, 21761261.41it/s]
# Total time: 21:59 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.649706</td>
#       <td>1.232579</td>
#       <td>0.489844</td>
#       <td>10:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.341478</td>
#       <td>0.931071</td>
#       <td>0.605469</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.074388</td>
# ...

# %%
learn = create_cnn(data,models.resnet34,metrics = accuracy)
learn.fit_one_cycle(10,1e-3,1e-2)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:105: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:02, 31074804.26it/s]
# Total time: 13:24 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.591927</td>
#       <td>1.189933</td>
#       <td>0.483594</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.289558</td>
#       <td>0.932899</td>
#       <td>0.590625</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.059961</td>
# ...

# %%
learn = create_cnn(data,models.resnet50,metrics = accuracy)
learn.fit_one_cycle(10,1e-3,1e-2)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:105: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Total time: 16:34 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.510096</td>
#       <td>1.162884</td>
#       <td>0.557813</td>
#       <td>01:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.306659</td>
#       <td>0.930793</td>
#       <td>0.620313</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.037278</td>
#       <td>0.818529</td>
#       <td>0.636719</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.864740</td>
#       <td>0.707353</td>
# ...

# %%
learn = create_cnn(data,models.resnet101,metrics = accuracy)
learn.fit_one_cycle(10,1e-3,1e-2)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:105: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.torch/models/resnet101-5d3b4d8f.pth
# 178728960it [00:03, 49349140.19it/s]
# Total time: 25:15 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.495178</td>
#       <td>1.140269</td>
#       <td>0.545313</td>
#       <td>02:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.241781</td>
#       <td>0.939379</td>
#       <td>0.617969</td>
#       <td>02:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.993670</td>
# ...

# %%
learn = create_cnn(data,models.densenet121,metrics = accuracy)
learn.fit_one_cycle(10,1e-3)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:105: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Total time: 16:37 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.542194</td>
#       <td>1.120461</td>
#       <td>0.551562</td>
#       <td>01:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.209013</td>
#       <td>0.862250</td>
#       <td>0.651563</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.970609</td>
#       <td>0.755269</td>
#       <td>0.673437</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.791726</td>
#       <td>0.741240</td>
# ...

# %%
learn = create_cnn(data,models.densenet161,metrics = accuracy)
learn.fit_one_cycle(10,1e-4)
